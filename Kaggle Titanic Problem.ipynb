# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_train=pd.read_csv('C:/Users/g.singh.choudhary/Desktop/Python/Kaggle Workplace/Titanic Problem/train.csv')
data_test=pd.read_csv('C:/Users/g.singh.choudhary/Desktop/Python/Kaggle Workplace/Titanic Problem/test.csv')
data_train.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                    Name   Sex  \
# count    891.000000  891.000000  891.000000                     891   891
# unique          NaN         NaN         NaN                     891     2
# top             NaN         NaN         NaN  Levy, Mr. Rene Jacques  male
# freq            NaN         NaN         NaN                       1   577
# mean     446.000000    0.383838    2.308642                     NaN   NaN
# std      257.353842    0.486592    0.836071                     NaN   NaN
# min        1.000000    0.000000    1.000000                     NaN   NaN
# 25%      223.500000    0.000000    2.000000                     NaN   NaN
# 50%      446.000000    0.000000    3.000000                     NaN   NaN
# 75%      668.500000    1.000000    3.000000                     NaN   NaN
# max      891.000000    1.000000    3.000000                     NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare Cabin  \
# ...

# %%
print(pd.isnull(data_train).sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
male_survived=data_train['Survived'][data_train['Sex']=='male'].value_counts(normalize=True)[1]*100
female_survived=data_train['Survived'][data_train['Sex']=='female'].value_counts(normalize=True)[1]*100
print(male_survived)
print(female_survived)
# Out:
# 18.8908145581
# 74.2038216561

# %%
data_train=data_train.drop(['Ticket'],axis=1)
data_test=data_test.drop(['Ticket'],axis=1)
data_train=data_train.drop(['Cabin'],axis=1)
data_test=data_test.drop(['Cabin'],axis=1)

# %%
print('Embarked =S ')
print(data_train[data_train['Embarked']=='S'].shape[0])
print('Embarked =C ')
print(data_train[data_train['Embarked']=='C'].shape[0])
print('Embarked =Q ')
print(data_train[data_train['Embarked']=='Q'].shape[0])
# Out:
# Embarked =S
# 644
# Embarked =C
# 168
# Embarked =Q
# 77

# %%
data_train=data_train.fillna({"Embarked":"S"})

# %%
data_train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                    Name   Sex  \
# count    891.000000  891.000000  891.000000                     891   891
# unique          NaN         NaN         NaN                     891     2
# top             NaN         NaN         NaN  Levy, Mr. Rene Jacques  male
# freq            NaN         NaN         NaN                       1   577
# mean     446.000000    0.383838    2.308642                     NaN   NaN
# std      257.353842    0.486592    0.836071                     NaN   NaN
# min        1.000000    0.000000    1.000000                     NaN   NaN
# 25%      223.500000    0.000000    2.000000                     NaN   NaN
# 50%      446.000000    0.000000    3.000000                     NaN   NaN
# 75%      668.500000    1.000000    3.000000                     NaN   NaN
# max      891.000000    1.000000    3.000000                     NaN   NaN
#
#                Age       SibSp       Parch        Fare Embarked
# ...

# %%
data_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked
# 0      0   7.2500        S
# 1      0  71.2833        C
# 2      0   7.9250        S
# 3      0  53.1000        S
# 4      0   8.0500        S

# %%
data_train=data_train.drop(['Name'],axis=1)

# %%
data_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
male_mean=data_train.loc[data_train['Sex']=='male','Age'].mean()
female_mean=data_train.loc[data_train['Sex']=='female','Age'].mean()

# %%
data_train.loc[(data_train['Sex']=='male')&(data_train['Age'].isnull()),'Age']=male_mean
data_train.loc[(data_train['Sex']=='female')&(data_train['Age'].isnull()),'Age']=female_mean

# %%
print(data_train['Age'].count())
# Out:
# 891

# %%
data_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
data_train=pd.get_dummies(data_train)

# %%
data_train.describe(include="all")
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.736034    0.523008
# std     257.353842    0.486592    0.836071   13.014897    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   30.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  Sex_female    Sex_male  Embarked_C  Embarked_Q  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.352413    0.647587    0.188552    0.086420
# std      0.806057   49.693429    0.477990    0.477990    0.391372    0.281141
# ...

# %%
data_train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  \
# 0            1         0       3  22.0      1      0   7.2500           0
# 1            2         1       1  38.0      1      0  71.2833           1
# 2            3         1       3  26.0      0      0   7.9250           1
# 3            4         1       1  35.0      1      0  53.1000           1
# 4            5         0       3  35.0      0      0   8.0500           0
#
#    Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0         1           0           0           1
# 1         0           1           0           0
# 2         0           0           0           1
# 3         0           0           0           1
# 4         1           0           0           1

# %%
X_train=data_train.loc[:,'Pclass':'Embarked_S']
y_train=data_train.loc[:,'Survived']

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print(lr.score(X_train,y_train))
# Out:
# 0.800224466891

# %%
data_test.describe(include='all')
# Out:
#         PassengerId      Pclass                      Name   Sex         Age  \
# count    418.000000  418.000000                       418   418  332.000000
# unique          NaN         NaN                       418     2         NaN
# top             NaN         NaN  Cribb, Miss. Laura Alice  male         NaN
# freq            NaN         NaN                         1   266         NaN
# mean    1100.500000    2.265550                       NaN   NaN   30.272590
# std      120.810458    0.841838                       NaN   NaN   14.181209
# min      892.000000    1.000000                       NaN   NaN    0.170000
# 25%      996.250000    1.000000                       NaN   NaN   21.000000
# 50%     1100.500000    3.000000                       NaN   NaN   27.000000
# 75%     1204.750000    3.000000                       NaN   NaN   39.000000
# max     1309.000000    3.000000                       NaN   NaN   76.000000
#
#              SibSp       Parch        Fare Embarked
# ...

# %%
data_test.loc[(data_test['Sex']=='male')&(data_test['Age'].isnull()),'Age']=male_mean
data_test.loc[(data_test['Sex']=='female')&(data_test['Age'].isnull()),'Age']=female_mean

# %%
data_test.describe(include='all')
# Out:
#         PassengerId      Pclass                      Name   Sex         Age  \
# count    418.000000  418.000000                       418   418  418.000000
# unique          NaN         NaN                       418     2         NaN
# top             NaN         NaN  Cribb, Miss. Laura Alice  male         NaN
# freq            NaN         NaN                         1   266         NaN
# mean    1100.500000    2.265550                       NaN   NaN   30.197890
# std      120.810458    0.841838                       NaN   NaN   12.648678
# min      892.000000    1.000000                       NaN   NaN    0.170000
# 25%      996.250000    1.000000                       NaN   NaN   23.000000
# 50%     1100.500000    3.000000                       NaN   NaN   29.000000
# 75%     1204.750000    3.000000                       NaN   NaN   35.750000
# max     1309.000000    3.000000                       NaN   NaN   76.000000
#
#              SibSp       Parch        Fare Embarked
# ...

# %%
data_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Embarked
# 0  34.5      0      0   7.8292        Q
# 1  47.0      1      0   7.0000        S
# 2  62.0      0      0   9.6875        Q
# 3  27.0      0      0   8.6625        S
# 4  22.0      1      1  12.2875        S

# %%
data_test=data_test.drop(['Name'],axis=1)

# %%
mean_fare=data_test['Fare'].mean()
data_test.loc[data_test['Fare'].isnull(),'Fare']=mean_fare

# %%
data_test=pd.get_dummies(data_test)

# %%
data_test.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0          892       3  34.5      0      0   7.8292           0         1
# 1          893       3  47.0      1      0   7.0000           1         0
# 2          894       2  62.0      0      0   9.6875           0         1
# 3          895       3  27.0      0      0   8.6625           0         1
# 4          896       3  22.0      1      1  12.2875           1         0
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           1           0
# 1           0           0           1
# 2           0           1           0
# 3           0           0           1
# 4           0           0           1

# %%
X_test=data_test.loc[:,'Pclass':'Embarked_S']

# %%
y_predict=lr.predict(X_test)

# %%
ids=data_test['PassengerId']

# %%
output=pd.DataFrame({'PassengerId':ids,'Survived':y_predict})

# %%
output.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
output.to_csv('titanic-predictions.csv', index = False)

# %%
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier()
forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_predict_forest=forest.predict(X_test)

# %%
output_forest=output=pd.DataFrame({'PassengerId':ids,'Survived':y_predict_forest})

# %%
output_forest.to_csv('titanic-predictions-random-forest.csv', index = False)
